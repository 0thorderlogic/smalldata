# %%
import numpy as np
import pandas as pd
import seaborn as sb

data = pd.read_csv('data/original_data.csv');
data.to_csv('temp/temp_ad3.csv', float_format='%.3f')

# %%
# Testing block

# prints the mean, median, mode, and other stat things.
str = input("Enter: ")
cut = data[str]
print(cut.describe())
# Out:
# count    211.000000
# mean      13.857820
# std        5.116451
# min        5.800000
# 25%        8.900000
# 50%       14.300000
# 75%       19.250000
# max       20.800000
# Name: PHP, dtype: float64

# %%
sb.regplot(x = 'Months', y = 'Python', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Python'>

# %%
sb.regplot(x='Months', y='Visual Basic', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Visual Basic'>

# %%
sb.regplot(x='Months', y='VBA', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='VBA'>

# %%
sb.regplot(x='Months', y='TypeScript', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='TypeScript'>

# %%
sb.regplot(x='Months', y='Swift', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Swift'>

# %%
sb.regplot(x='Months', y='Scala', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Scala'>

# %%
sb.regplot(x='Months', y='Rust', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Rust'>

# %%
sb.regplot(x='Months', y='Ruby', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Ruby'>

# %%
sb.regplot(x='Months', y='R', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='R'>

# %%
sb.regplot(x='Months', y='Python', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Python'>

# %%
sb.regplot(x='Months', y='PHP', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='PHP'>

# %%
sb.regplot(x='Months', y='Perl', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Perl'>

# %%
sb.regplot(x='Months', y='Objective-C', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Objective-C'>

# %%
sb.regplot(x='Months', y='Matlab', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Matlab'>

# %%
sb.regplot(x='Months', y='Lua', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Lua'>

# %%
sb.regplot(x='Months', y='Kotlin', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Kotlin'>

# %%
sb.regplot(x='Months', y='Julia', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Julia'>

# %%
sb.regplot(x='Months', y='JavaScript', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='JavaScript'>

# %%
sb.regplot(x='Months', y='Java', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Java'>

# %%
sb.regplot(x='Months', y='Haskell', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Haskell'>

# %%
sb.regplot(x='Months', y='Groovy', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Groovy'>

# %%
sb.regplot(x='Months', y='Go', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Go'>

# %%
sb.regplot(x='Months', y='Delphi/Pascal', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Delphi/Pascal'>

# %%
sb.regplot(x='Months', y='Dart', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Dart'>

# %%
sb.regplot(x='Months', y='Cobol', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Cobol'>

# %%
sb.regplot(x='Months', y='C#', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='C#'>

# %%
sb.regplot(x='Months', y='C/C++', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='C/C++'>

# %%
sb.regplot(x='Months', y='Ada', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Ada'>

# %%
sb.regplot(x='Months', y='Abap', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Abap'>
