# %%
import numpy as np
import pandas as pd
import seaborn as sb

data = pd.read_csv('original_data.csv');

# %%
data # should produce data like 0.000000000005
# Out:
#      Unnamed: 0            Date  Abap  Ada  C/C++   C#  Cobol  Dart  \
# 0             0       July 2004   0.3  0.4   10.1  4.7    0.4   0.0
# 1             1     August 2004   0.4  0.4    9.8  5.0    0.5   0.0
# 2             2  September 2004   0.4  0.4    9.6  5.1    0.5   0.0
# 3             3    October 2004   0.4  0.4    9.5  5.3    0.5   0.0
# 4             4   November 2004   0.4  0.4    9.5  5.2    0.5   0.0
# ..          ...             ...   ...  ...    ...  ...    ...   ...
# 206         206  September 2021   0.5  0.5    6.7  7.2    0.3   0.6
# 207         207    October 2021   0.5  0.6    7.0  7.4    0.3   0.5
# 208         208   November 2021   0.6  0.7    7.0  7.3    0.3   0.6
# 209         209   December 2021   0.7  0.7    7.0  7.3    0.3   0.7
# 210         210    January 2022   0.7  0.8    7.4  7.3    0.3   0.7
#
#      Delphi/Pascal   Go  ...   PHP  Python    R  Ruby  Rust  Scala  Swift  \
# 0              2.8  0.0  ...  18.8     2.5  0.4   0.3   0.1    0.0    0.0
# ...

# %%
data.to_csv('modified.csv', float_format='%.3f')

data # should produce smaller decimal points
# Out:
#      Unnamed: 0            Date  Abap  Ada  C/C++   C#  Cobol  Dart  \
# 0             0       July 2004   0.3  0.4   10.1  4.7    0.4   0.0
# 1             1     August 2004   0.4  0.4    9.8  5.0    0.5   0.0
# 2             2  September 2004   0.4  0.4    9.6  5.1    0.5   0.0
# 3             3    October 2004   0.4  0.4    9.5  5.3    0.5   0.0
# 4             4   November 2004   0.4  0.4    9.5  5.2    0.5   0.0
# ..          ...             ...   ...  ...    ...  ...    ...   ...
# 206         206  September 2021   0.5  0.5    6.7  7.2    0.3   0.6
# 207         207    October 2021   0.5  0.6    7.0  7.4    0.3   0.5
# 208         208   November 2021   0.6  0.7    7.0  7.3    0.3   0.6
# 209         209   December 2021   0.7  0.7    7.0  7.3    0.3   0.7
# 210         210    January 2022   0.7  0.8    7.4  7.3    0.3   0.7
#
#      Delphi/Pascal   Go  ...   PHP  Python    R  Ruby  Rust  Scala  Swift  \
# 0              2.8  0.0  ...  18.8     2.5  0.4   0.3   0.1    0.0    0.0
# ...

# %%
sb.regplot(x='Date', y='Python', data = data)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 sb.regplot(x='Date', y='Python', data = data)
#
# File ~/.local/lib/python3.11/site-packages/seaborn/regression.py:759, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     757 scatter_kws["marker"] = marker
#     758 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 759 plotter.plot(ax, scatter_kws, line_kws)
#     760 return ax
#
# File ~/.local/lib/python3.11/site-packages/seaborn/regression.py:368, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     365     self.scatterplot(ax, scatter_kws)
#     367 if self.fit_reg:
# --> 368     self.lineplot(ax, line_kws)
# ...

# %%
data.ruby = data.sort_values('Ruby')
# Out:
# /tmp/ipykernel_6643/1487257098.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.ruby = data.sort_values('Ruby')
