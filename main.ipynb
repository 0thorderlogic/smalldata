# %%
import numpy as np
import pandas as pd
import seaborn as sb

data = pd.read_csv('original_data.csv');

# %%
# un-modified data
# there is a backup file named as "data.csv" don't touch that.
data # should produce data like 0.000000000005
# Out:
#       SL            Date  Abap  Ada  C/C++   C#  Cobol  Dart  Delphi/Pascal  \
# 0      0       July 2004   0.3  0.4   10.1  4.7    0.4   0.0            2.8
# 1      1     August 2004   0.4  0.4    9.8  5.0    0.5   0.0            2.7
# 2      2  September 2004   0.4  0.4    9.6  5.1    0.5   0.0            2.6
# 3      3    October 2004   0.4  0.4    9.5  5.3    0.5   0.0            2.8
# 4      4   November 2004   0.4  0.4    9.5  5.2    0.5   0.0            2.8
# ..   ...             ...   ...  ...    ...  ...    ...   ...            ...
# 206  206  September 2021   0.5  0.5    6.7  7.2    0.3   0.6            0.0
# 207  207    October 2021   0.5  0.6    7.0  7.4    0.3   0.5            0.0
# 208  208   November 2021   0.6  0.7    7.0  7.3    0.3   0.6            0.0
# 209  209   December 2021   0.7  0.7    7.0  7.3    0.3   0.7            0.0
# 210  210    January 2022   0.7  0.8    7.4  7.3    0.3   0.7            0.0
#
#       Go  ...   PHP  Python    R  Ruby  Rust  Scala  Swift  TypeScript  VBA  \
# 0    0.0  ...  18.8     2.5  0.4   0.3   0.1    0.0    0.0         0.0  1.4
# 1    0.0  ...  19.3     2.6  0.4   0.4   0.1    0.0    0.0         0.0  1.5
# 2    0.0  ...  19.5     2.7  0.4   0.4   0.1    0.0    0.0         0.0  1.6
# 3    0.0  ...  19.3     2.9  0.4   0.5   0.1    0.0    0.0         0.0  1.6
# 4    0.0  ...  19.4     2.8  0.4   0.4   0.1    0.0    0.0         0.0  1.5
# ..   ...  ...   ...     ...  ...   ...   ...    ...    ...         ...  ...
# 206  1.6  ...   6.4    30.1  3.9   1.0   0.8    0.5    1.6         1.6  1.3
# 207  1.5  ...   6.3    30.1  3.7   1.0   0.7    0.5    1.6         1.6  1.3
# 208  1.4  ...   6.2    30.1  3.8   1.0   0.8    0.5    1.7         1.6  1.4
# 209  1.4  ...   6.2    29.6  4.1   1.0   0.8    0.5    1.6         1.7  1.2
# 210  1.2  ...   6.1    28.7  4.2   1.1   1.0    0.5    1.9         1.7  1.1
#
#      Visual Basic
# 0             8.6
# 1             8.6
# 2             8.4
# 3             8.5
# 4             8.2
# ..            ...
# 206           0.7
# 207           0.8
# 208           0.8
# 209           0.7
# 210           0.6
#
# [211 rows x 30 columns]

# %%
data.to_csv('modified.csv', float_format='%.3f')

data # should produce smaller decimal points
# Out:
#       SL            Date  Abap  Ada  C/C++   C#  Cobol  Dart  Delphi/Pascal  \
# 0      0       July 2004   0.3  0.4   10.1  4.7    0.4   0.0            2.8
# 1      1     August 2004   0.4  0.4    9.8  5.0    0.5   0.0            2.7
# 2      2  September 2004   0.4  0.4    9.6  5.1    0.5   0.0            2.6
# 3      3    October 2004   0.4  0.4    9.5  5.3    0.5   0.0            2.8
# 4      4   November 2004   0.4  0.4    9.5  5.2    0.5   0.0            2.8
# ..   ...             ...   ...  ...    ...  ...    ...   ...            ...
# 206  206  September 2021   0.5  0.5    6.7  7.2    0.3   0.6            0.0
# 207  207    October 2021   0.5  0.6    7.0  7.4    0.3   0.5            0.0
# 208  208   November 2021   0.6  0.7    7.0  7.3    0.3   0.6            0.0
# 209  209   December 2021   0.7  0.7    7.0  7.3    0.3   0.7            0.0
# 210  210    January 2022   0.7  0.8    7.4  7.3    0.3   0.7            0.0
#
#       Go  ...   PHP  Python    R  Ruby  Rust  Scala  Swift  TypeScript  VBA  \
# 0    0.0  ...  18.8     2.5  0.4   0.3   0.1    0.0    0.0         0.0  1.4
# 1    0.0  ...  19.3     2.6  0.4   0.4   0.1    0.0    0.0         0.0  1.5
# 2    0.0  ...  19.5     2.7  0.4   0.4   0.1    0.0    0.0         0.0  1.6
# 3    0.0  ...  19.3     2.9  0.4   0.5   0.1    0.0    0.0         0.0  1.6
# 4    0.0  ...  19.4     2.8  0.4   0.4   0.1    0.0    0.0         0.0  1.5
# ..   ...  ...   ...     ...  ...   ...   ...    ...    ...         ...  ...
# 206  1.6  ...   6.4    30.1  3.9   1.0   0.8    0.5    1.6         1.6  1.3
# 207  1.5  ...   6.3    30.1  3.7   1.0   0.7    0.5    1.6         1.6  1.3
# 208  1.4  ...   6.2    30.1  3.8   1.0   0.8    0.5    1.7         1.6  1.4
# 209  1.4  ...   6.2    29.6  4.1   1.0   0.8    0.5    1.6         1.7  1.2
# 210  1.2  ...   6.1    28.7  4.2   1.1   1.0    0.5    1.9         1.7  1.1
#
#      Visual Basic
# 0             8.6
# 1             8.6
# 2             8.4
# 3             8.5
# 4             8.2
# ..            ...
# 206           0.7
# 207           0.8
# 208           0.8
# 209           0.7
# 210           0.6
#
# [211 rows x 30 columns]

# %% [markdown]
# ## Case 1
#
#  Covers languages that are still as popular as they where in 2004

# %%
sb.regplot(x='SL', y='PHP', data = data)
# Out:
# <Axes: xlabel='SL', ylabel='PHP'>

# %% [markdown]
# ## Case 2
#
# Covers languages that were popular and are no longer popular.

# %%
sb.regplot(x='SL', y='Python', data = data)
# Out:
# <Axes: xlabel='SL', ylabel='Python'>

# %% [markdown]
# ## Case 3
#
# Covers languages that have become popular in the recent years.

# %%
sb.regplot(x='SL', y='C/C++', data = data)
# Out:
# <Axes: xlabel='SL', ylabel='C/C++'>

# %%
## Case 4

Covers languages that never took off.

# %%
# sb.regplot(x='SL', y='LANGUAGE NAME', data = data)
