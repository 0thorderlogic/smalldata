# %%
import numpy as np
import pandas as pd
import seaborn as sb

data = pd.read_csv('data/original_data.csv');
data.to_csv('temp/temp_modified.csv', float_format='%.3f')

# %% [markdown]
# ## Case 1
#
# Covers languages that are still as popular as they where in 2004
#
# 1. JavaScript

# %%
sb.lineplot(x='Months', y='JavaScript', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='JavaScript'>

# %% [markdown]
# ## Case 2
#
# Covers languages that were popular and are no longer popular.
#
# 1. Visual Basic
# 1. PHP
# 1. Perl
# 1. Java

# %%
sb.lineplot(x='Months', y='Visual Basic', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Visual Basic'>

# %%
sb.lineplot(x='Months', y='PHP', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='PHP'>

# %%
sb.lineplot(x='Months', y='Perl', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Perl'>

# %%
sb.lineplot(x='Months', y='Java', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Java'>

# %% [markdown]
# ## Case 3
#
# Covers languages that have become popular.
#
# 1. Python

# %%
sb.lineplot(x='Months', y='Python', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Python'>

# %% [markdown]
# ## Case 4
#
# Covers languages that never took off.
#
# 1. VBA
# 2. Scala
# 3. Rust
# 4. Lua
# 5. Delphi/Pascal
# 6. Cobol
# 7. Ada
# 8. Abap

# %%
sb.lineplot(x='Months', y='VBA', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='VBA'>

# %%
sb.lineplot(x='Months', y='Scala', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Scala'>

# %%
sb.lineplot(x='Months', y='Rust', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Rust'>

# %%
sb.lineplot(x='Months', y='Lua', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Lua'>

# %%
sb.lineplot(x='Months', y='Delphi/Pascal', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Delphi/Pascal'>

# %%
sb.lineplot(x='Months', y='Cobol', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Cobol'>

# %%
sb.lineplot(x='Months', y='Ada', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Ada'>

# %%
sb.lineplot(x='Months', y='Abap', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Abap'>

# %% [markdown]
# ## Special Case 1
#
# "Mid for life"
#
# 1. Swift
# 1. Ruby
# 1. Onjective-C
# 1. Matlab
# 1. Kotlin
# 1. Julia
# 1. Haskell
# 1. C#
# 1. C/C++

# %%
sb.lineplot(x='Months', y='Swift', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Swift'>

# %%
sb.lineplot(x='Months', y='Ruby', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Ruby'>

# %%
sb.lineplot(x='Months', y='Objective-C', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Objective-C'>

# %%
sb.lineplot(x='Months', y='Matlab', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Matlab'>

# %%
sb.lineplot(x='Months', y='Kotlin', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Kotlin'>

# %%
sb.lineplot(x='Months', y='Julia', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Julia'>

# %%
sb.lineplot(x='Months', y='Haskell', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='Haskell'>

# %%
sb.lineplot(x='Months', y='C#', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='C#'>

# %%
sb.lineplot(x='Months', y='C/C++', data=data)
# Out:
# <Axes: xlabel='Months', ylabel='C/C++'>

# %% [markdown]
# ## Special Section 2
#
# Gaining Popularity
#
# 1. TypeScript
# 1. R
# 1. Groovy
# 1. Go
# 1. Dart

# %%
sb.lineplot(x='Months', y='TypeScript', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='TypeScript'>

# %%
sb.lineplot(x='Months', y='R', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='R'>

# %%
sb.lineplot(x='Months', y='Groovy', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Groovy'>

# %%
sb.lineplot(x='Months', y='Go', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Go'>

# %%
sb.lineplot(x='Months', y='Dart', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Dart'>
