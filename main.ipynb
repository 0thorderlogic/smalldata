# %%
import numpy as np
import pandas as pd
import seaborn as sb

data = pd.read_csv('original_data.csv');

# %%
# un-modified data
# there is a backup file named as "data.csv" don't touch that.
data # should produce data like 0.000000000005
# Out:
#      Months            Date  Abap  Ada  C/C++   C#  Cobol  Dart  \
# 0         0       July 2004   0.3  0.4   10.1  4.7    0.4   0.0
# 1         1     August 2004   0.4  0.4    9.8  5.0    0.5   0.0
# 2         2  September 2004   0.4  0.4    9.6  5.1    0.5   0.0
# 3         3    October 2004   0.4  0.4    9.5  5.3    0.5   0.0
# 4         4   November 2004   0.4  0.4    9.5  5.2    0.5   0.0
# ..      ...             ...   ...  ...    ...  ...    ...   ...
# 206     206  September 2021   0.5  0.5    6.7  7.2    0.3   0.6
# 207     207    October 2021   0.5  0.6    7.0  7.4    0.3   0.5
# 208     208   November 2021   0.6  0.7    7.0  7.3    0.3   0.6
# 209     209   December 2021   0.7  0.7    7.0  7.3    0.3   0.7
# 210     210    January 2022   0.7  0.8    7.4  7.3    0.3   0.7
#
#      Delphi/Pascal   Go  ...   PHP  Python    R  Ruby  Rust  Scala  Swift  \
# 0              2.8  0.0  ...  18.8     2.5  0.4   0.3   0.1    0.0    0.0
# ...

# %%
data.to_csv('modified.csv', float_format='%.3f')

data # should produce smaller decimal points
# Out:
#      Months            Date  Abap  Ada  C/C++   C#  Cobol  Dart  \
# 0         0       July 2004   0.3  0.4   10.1  4.7    0.4   0.0
# 1         1     August 2004   0.4  0.4    9.8  5.0    0.5   0.0
# 2         2  September 2004   0.4  0.4    9.6  5.1    0.5   0.0
# 3         3    October 2004   0.4  0.4    9.5  5.3    0.5   0.0
# 4         4   November 2004   0.4  0.4    9.5  5.2    0.5   0.0
# ..      ...             ...   ...  ...    ...  ...    ...   ...
# 206     206  September 2021   0.5  0.5    6.7  7.2    0.3   0.6
# 207     207    October 2021   0.5  0.6    7.0  7.4    0.3   0.5
# 208     208   November 2021   0.6  0.7    7.0  7.3    0.3   0.6
# 209     209   December 2021   0.7  0.7    7.0  7.3    0.3   0.7
# 210     210    January 2022   0.7  0.8    7.4  7.3    0.3   0.7
#
#      Delphi/Pascal   Go  ...   PHP  Python    R  Ruby  Rust  Scala  Swift  \
# 0              2.8  0.0  ...  18.8     2.5  0.4   0.3   0.1    0.0    0.0
# ...

# %% [markdown]
# ## Case 1
#
#  Covers languages that are still as popular as they where in 2004
#
#  1.

# %%
sb.regplot(x='Months', y='PHP', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='VBA'>

# %% [markdown]
# ## Case 2
#
# Covers languages that were popular and are no longer popular.

# %%
sb.regplot(x='Months', y='Python', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='Python'>

# %% [markdown]
# ## Case 3
#
# Covers languages that have become popular in the recent years.

# %%
sb.regplot(x='Months', y='C/C++', data = data)
# Out:
# <Axes: xlabel='Months', ylabel='C/C++'>

# %%
## Case 4

Covers languages that never took off.

# %%
# sb.regplot(x='SL', y='LANGUAGE NAME', data = data)
